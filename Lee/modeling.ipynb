# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn

# %%
df = pd.read_csv('../data/02_processed/churn_data_modeling.csv')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14605 entries, 0 to 14604
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      14605 non-null  int64
#  1   id                              14605 non-null  object
#  2   channel_sales                   14605 non-null  object
#  3   cons_12m                        14605 non-null  int64
#  4   cons_gas_12m                    14605 non-null  int64
#  5   cons_last_month                 14605 non-null  int64
#  6   date_activ                      14605 non-null  object
#  7   date_end                        14605 non-null  object
#  8   date_modif_prod                 14605 non-null  object
#  9   date_renewal                    14605 non-null  object
#  10  forecast_cons_12m               14605 non-null  float64
#  11  forecast_cons_year              14605 non-null  int64
#  12  forecast_discount_energy        14605 non-null  float64
#  13  forecast_meter_rent_12m         14605 non-null  float64
#  14  forecast_price_energy_off_peak  14605 non-null  float64
#  15  forecast_price_energy_peak      14605 non-null  float64
#  16  forecast_price_pow_off_peak     14605 non-null  float64
#  17  has_gas                         14605 non-null  object
#  18  imp_cons                        14605 non-null  float64
#  19  margin_gross_pow_ele            14605 non-null  float64
#  20  margin_net_pow_ele              14605 non-null  float64
#  21  nb_prod_act                     14605 non-null  int64
#  22  net_margin                      14605 non-null  float64
#  23  num_years_antig                 14605 non-null  int64
#  24  origin_up                       14605 non-null  object
#  25  pow_max                         14605 non-null  float64
#  26  mean_year_price_off_peak_var_x  14605 non-null  float64
#  27  mean_year_price_peak_var_x      14605 non-null  float64
#  28  mean_year_price_mid_peak_var_x  14605 non-null  float64
#  29  mean_year_price_off_peak_fix_x  14605 non-null  float64
#  30  mean_year_price_peak_fix_x      14605 non-null  float64
#  31  mean_year_price_mid_peak_fix_x  14605 non-null  float64
#  32  mean_year_price_off_peak_x      14605 non-null  float64
#  33  mean_year_price_peak_x          14605 non-null  float64
#  34  mean_year_price_med_peak_x      14605 non-null  float64
#  35  mean_year_price_off_peak_var_y  14605 non-null  float64
#  36  mean_year_price_peak_var_y      14605 non-null  float64
#  37  mean_year_price_mid_peak_var_y  14605 non-null  float64
#  38  mean_year_price_off_peak_fix_y  14605 non-null  float64
#  39  mean_year_price_peak_fix_y      14605 non-null  float64
#  40  mean_year_price_mid_peak_fix_y  14605 non-null  float64
#  41  mean_year_price_off_peak_y      14605 non-null  float64
#  42  mean_year_price_peak_y          14605 non-null  float64
#  43  mean_year_price_med_peak_y      14605 non-null  float64
#  44  mean_year_price_off_peak_var    14605 non-null  float64
#  45  mean_year_price_peak_var        14605 non-null  float64
#  46  mean_year_price_mid_peak_var    14605 non-null  float64
#  47  mean_year_price_off_peak_fix    14605 non-null  float64
#  48  mean_year_price_peak_fix        14605 non-null  float64
#  49  mean_year_price_mid_peak_fix    14605 non-null  float64
#  50  mean_year_price_off_peak        14605 non-null  float64
#  51  mean_year_price_peak            14605 non-null  float64
#  52  mean_year_price_med_peak        14605 non-null  float64
#  53  churn                           14605 non-null  int64
# dtypes: float64(38), int64(8), object(8)
# memory usage: 6.0+ MB

# %%
df.head()
# Out:
#    Unnamed: 0                                id  \
# 0           0  24011ae4ebbe3035111d65fa7c15bc57
# 1           1  d29c2c54acc38ff3c0614d0a653813dd
# 2           2  764c75f661154dac3a6c254cd082ea7d
# 3           3  bba03439a292a1e166f80264c16191cb
# 4           4  149d57cf92fc41cf94415803a877cb4b
#
#                       channel_sales  cons_12m  cons_gas_12m  cons_last_month  \
# 0  foosdfpfkusacimwkcsosbicdxkicaua         0         54946                0
# 1                           MISSING      4660             0                0
# 2  foosdfpfkusacimwkcsosbicdxkicaua       544             0                0
# 3  lmkebamcaaclubfxadlmueccxoimlema      1584             0                0
# 4                           MISSING      4425             0              526
#
#    date_activ    date_end date_modif_prod date_renewal  ...  \
# 0  2013-06-15  2016-06-15      2015-11-01   2015-06-23  ...
# 1  2009-08-21  2016-08-30      2009-08-21   2015-08-31  ...
# 2  2010-04-16  2016-04-16      2010-04-16   2015-04-17  ...
# 3  2010-03-30  2016-03-30      2010-03-30   2015-03-31  ...
# 4  2010-01-13  2016-03-07      2010-01-13   2015-03-09  ...
#
#    mean_year_price_off_peak_var  mean_year_price_peak_var  \
# 0                      0.131756                  0.092638
# 1                      0.147600                  0.000000
# 2                      0.167798                  0.088409
# 3                      0.148586                  0.000000
# 4                      0.119906                  0.101673
#
#    mean_year_price_mid_peak_var  mean_year_price_off_peak_fix  \
# 0                      0.036909                     42.497907
# 1                      0.000000                     44.444710
# 2                      0.000000                     44.444710
# 3                      0.000000                     44.444710
# 4                      0.073719                     40.728885
#
#    mean_year_price_peak_fix  mean_year_price_mid_peak_fix  \
# 0                 12.218665                      8.145777
# 1                  0.000000                      0.000000
# 2                  0.000000                      0.000000
# 3                  0.000000                      0.000000
# 4                 24.437330                     16.291555
#
#    mean_year_price_off_peak mean_year_price_peak  mean_year_price_med_peak  \
# 0                 42.629663            12.311304                  8.182687
# 1                 44.592310             0.000000                  0.000000
# 2                 44.612508             0.088409                  0.000000
# 3                 44.593296             0.000000                  0.000000
# 4                 40.848791            24.539003                 16.365274
#
#    churn
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#
# [5 rows x 54 columns]

# %%
X = df.drop('churn', axis=1).to_numpy()
y = df['churn'].to_numpy()
X.shape, y.shape
# Out:
# ((14605, 53), (14605,))

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train, X_test, y_train, y_test = train_test_split(X, y)

X_scaler = StandardScaler()
X_train_scaled = X_scaler.fit_transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
categoric_df = df.select_dtypes(include='object')
categoric_df
# Out:
#                                      id                     channel_sales  \
# 0      24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1      d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2      764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3      bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4      149d57cf92fc41cf94415803a877cb4b                           MISSING
# ...                                 ...                               ...
# 14600  18463073fb097fc0ac5d3e040f356987  foosdfpfkusacimwkcsosbicdxkicaua
# 14601  d0a6f71671571ed83b2645d23af6de00  foosdfpfkusacimwkcsosbicdxkicaua
# 14602  10e6828ddd62cbcf687cb74928c4c2d2  foosdfpfkusacimwkcsosbicdxkicaua
# 14603  1cf20fd6206d7678d5bcafd28c53b4db  foosdfpfkusacimwkcsosbicdxkicaua
# 14604  563dde550fd624d7352f3de77c0cdfcd                           MISSING
#
#        date_activ    date_end date_modif_prod date_renewal has_gas  \
# 0      2013-06-15  2016-06-15      2015-11-01   2015-06-23       t
# 1      2009-08-21  2016-08-30      2009-08-21   2015-08-31       f
# 2      2010-04-16  2016-04-16      2010-04-16   2015-04-17       f
# 3      2010-03-30  2016-03-30      2010-03-30   2015-03-31       f
# 4      2010-01-13  2016-03-07      2010-01-13   2015-03-09       f
# ...           ...         ...             ...          ...     ...
# 14600  2012-05-24  2016-05-08      2015-05-08   2014-05-26       t
# 14601  2012-08-27  2016-08-27      2012-08-27   2015-08-28       f
# 14602  2012-02-08  2016-02-07      2012-02-08   2015-02-09       f
# 14603  2012-08-30  2016-08-30      2012-08-30   2015-08-31       f
# 14604  2009-12-18  2016-12-17      2009-12-18   2015-12-21       f
#
#                               origin_up
# 0      lxidpiddsbxsbosboudacockeimpuepw
# 1      kamkkxfxxuwbdslkwifmmcsiusiuosws
# 2      kamkkxfxxuwbdslkwifmmcsiusiuosws
# 3      kamkkxfxxuwbdslkwifmmcsiusiuosws
# 4      kamkkxfxxuwbdslkwifmmcsiusiuosws
# ...                                 ...
# 14600  lxidpiddsbxsbosboudacockeimpuepw
# 14601  lxidpiddsbxsbosboudacockeimpuepw
# 14602  lxidpiddsbxsbosboudacockeimpuepw
# 14603  lxidpiddsbxsbosboudacockeimpuepw
# 14604  ldkssxwpmemidmecebumciepifcamkci
#
# [14605 rows x 8 columns]

# %%
from catboost import Pool, CatBoostClassifier
# 데이터 Pool 작업
cat_features = ['gender','region','membership_type']
train_pool = Pool(X_train, y_train, cat_features=cat_features)
test_pool = Pool(X_test, y_test, cat_features=cat_features)

model = CatBoostClassifier(
    random_state=0,
    iterations=1000,   # 반복횟수
    learning_rate=0.1,
    eval_metric='Accuracy',
    verbose=10
)
model.fit(train_pool, eval_set=test_pool)

# 모델 평가
print(f'학습 Acc: {model.score(X_train, y_train)}')
print(f'평가 Acc: {model.score(X_test, y_test)}')
